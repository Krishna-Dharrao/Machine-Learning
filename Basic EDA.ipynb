# %% [markdown]
# # EDA

# %%
import pandas as pd
df=pd.read_csv('/Users/ADMIN/MLA/Salaries.csv')
df
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %%
df1=pd.DataFrame(df)
df1.iloc[:10]
# Out:
#    Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0           1       Prof          B             19           18    Male
# 1           2       Prof          B             20           16    Male
# 2           3   AsstProf          B              4            3    Male
# 3           4       Prof          B             45           39    Male
# 4           5       Prof          B             40           41    Male
# 5           6  AssocProf          B              6            6    Male
# 6           7       Prof          B             30           23    Male
# 7           8       Prof          B             45           45    Male
# 8           9       Prof          B             21           20    Male
# 9          10       Prof          B             18           18  Female
#
#    salary
# 0  139750
# 1  173200
# 2   79750
# 3  115000
# 4  141500
# 5   97000
# 6  175000
# 7  147765
# 8  119250
# 9  129000

# %%
df1.iloc[:20]
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0            1       Prof          B             19           18    Male
# 1            2       Prof          B             20           16    Male
# 2            3   AsstProf          B              4            3    Male
# 3            4       Prof          B             45           39    Male
# 4            5       Prof          B             40           41    Male
# 5            6  AssocProf          B              6            6    Male
# 6            7       Prof          B             30           23    Male
# 7            8       Prof          B             45           45    Male
# 8            9       Prof          B             21           20    Male
# 9           10       Prof          B             18           18  Female
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# ...

# %%
df1.iloc[:50]
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0            1       Prof          B             19           18    Male
# 1            2       Prof          B             20           16    Male
# 2            3   AsstProf          B              4            3    Male
# 3            4       Prof          B             45           39    Male
# 4            5       Prof          B             40           41    Male
# 5            6  AssocProf          B              6            6    Male
# 6            7       Prof          B             30           23    Male
# 7            8       Prof          B             45           45    Male
# 8            9       Prof          B             21           20    Male
# 9           10       Prof          B             18           18  Female
# 10          11  AssocProf          B             12            8    Male
# 11          12   AsstProf          B              7            2    Male
# ...

# %%
df1.shape
# Out:
# (397, 7)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'discipline', 'yrs.since.phd', 'yrs.service',
#        'sex', 'salary'],
#       dtype='object')

# %%
for cols in df1.columns:
    print(type(cols))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df1.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
df1['salary'].mean()
# Out:
# 113706.45843828715

# %%
df1['salary'].count()
# Out:
# 397

# %%
df1.head(50).mean()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_12796/3569922619.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.head(50).mean()
# Unnamed: 0           25.50
# yrs.since.phd        20.92
# yrs.service          16.22
# salary           112625.64
# dtype: float64

# %%
df1['salary'].describe()
# Out:
# count       397.000000
# mean     113706.458438
# std       30289.038695
# min       57800.000000
# 25%       91000.000000
# 50%      107300.000000
# 75%      134185.000000
# max      231545.000000
# Name: salary, dtype: float64

# %%
df1.groupby('rank').mean()
# Out:
#            Unnamed: 0  yrs.since.phd  yrs.service         salary
# rank
# AssocProf  179.828125      15.453125    11.953125   93876.437500
# AsstProf   169.761194       5.104478     2.373134   80775.985075
# Prof       210.977444      28.300752    22.815789  126772.109023

# %%
df1.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     93876.437500
# AsstProf      80775.985075
# Prof         126772.109023
# Name: salary, dtype: float64

# %%
df2=df1.where(df1['sex']=='Female')
df2.dropna()
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 9          10.0       Prof          B           18.0         18.0  Female
# 19         20.0       Prof          A           39.0         36.0  Female
# 24         25.0  AssocProf          A           13.0          8.0  Female
# 34         35.0   AsstProf          B            4.0          2.0  Female
# 35         36.0   AsstProf          B            5.0          0.0  Female
# 47         48.0       Prof          B           23.0         19.0  Female
# 48         49.0       Prof          B           25.0         25.0  Female
# 52         53.0   AsstProf          B           11.0          3.0  Female
# 63         64.0  AssocProf          B           11.0         11.0  Female
# 68         69.0       Prof          B           17.0         17.0  Female
# 84         85.0       Prof          B           17.0         18.0  Female
# 90         91.0   AsstProf          B           10.0          5.0  Female
# ...

# %%
df2.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count   39.000000      39.000000    39.000000      39.000000
# mean   171.000000      16.512821    11.564103  101002.410256
# std    109.057204       9.784176     8.813252   25952.127317
# min     10.000000       2.000000     0.000000   62884.000000
# 25%     77.000000      10.000000     4.000000   77250.000000
# 50%    149.000000      17.000000    10.000000  103750.000000
# 75%    250.000000      23.500000    17.500000  117002.500000
# max    362.000000      39.000000    36.000000  161101.000000
